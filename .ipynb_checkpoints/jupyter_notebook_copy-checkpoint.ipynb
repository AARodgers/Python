# %% [markdown]
# Amanda Rodgers
# May 10, 2024
# Best Selling Books
# Statistics Practice

# %%
# import modules 
import matplotlib.pyplot as mp 
import pandas as pd 
import seaborn as sb

# %%
# import file with data 
data = pd.read_csv("/Users/amandarodgers/Documents/Data_Bootcamp/Python/data_sets/bestsellers.csv")

# %%
data.head(10)
# Out:
#                                                 Name               Author  \
# 0                                    A Promised Land         Barack Obama
# 1  Too Much and Never Enough: How My Family Creat...  Mary L. Trump Ph.D.
# 2                            Where the Crawdads Sing          Delia Owens
# 3  My First Learn to Write Workbook: Practice for...        Crystal Radke
# 4                                       Midnight Sun      Stephenie Meyer
# 5                                            Untamed        Glennon Doyle
# 6                       If Animals Kissed Good Night    Ann Whitford Paul
# 7  White Fragility: Why It's So Hard for White Pe...       Robin DiAngelo
# 8  School Zone - Big Preschool Workbook - Ages 3 ...          School Zone
# 9   The Room Where It Happened: A White House Memoir          John Bolton
#
#    Rating   Reviews        Type  Price(USD)  Year
# 0     4.9   44472.0   Hardcover       19.94  2020
# 1     4.6   85837.0   Hardcover       19.38  2020
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        2600 non-null   object
#  1   Author      2590 non-null   object
#  2   Rating      2587 non-null   float64
#  3   Reviews     2583 non-null   float64
#  4   Type        2590 non-null   object
#  5   Price(USD)  2589 non-null   float64
#  6   Year        2600 non-null   int64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 142.3+ KB

# %%
data.describe()
# Out:
#             Rating        Reviews   Price(USD)         Year
# count  2587.000000    2583.000000  2589.000000  2600.000000
# mean      4.530035    8211.066589    12.358957  2007.500000
# std       0.326940   12616.370288    14.813445     7.501443
# min       1.000000       1.000000     0.010000  1995.000000
# 25%       4.400000     715.000000     1.610000  2001.000000
# 50%       4.600000    3369.000000    11.950000  2007.500000
# 75%       4.700000   10600.500000    17.280000  2014.000000
# max       5.000000  129991.000000   379.990000  2020.000000

# %%
filtered_data = data[['Rating', 'Reviews', 'Price(USD)', 'Year']]
filtered_data
filtered_data.head(5)
# Out:
#    Rating   Reviews  Price(USD)  Year
# 0     4.9   44472.0       19.94  2020
# 1     4.6   85837.0       19.38  2020
# 2     4.8  129991.0        3.50  2020
# 3     4.8   39679.0        1.99  2020
# 4     4.8   55750.0       13.32  2020

# %%
# prints data that will be plotted 
# columns shown here are selected by corr() since 
# they are ideal for the plot 
print(filtered_data.corr())
# Out:
#               Rating   Reviews  Price(USD)      Year
# Rating      1.000000  0.256197   -0.084379  0.345113
# Reviews     0.256197  1.000000   -0.163811  0.479003
# Price(USD) -0.084379 -0.163811    1.000000 -0.210814
# Year        0.345113  0.479003   -0.210814  1.000000

# %%
# plotting correlation heatmap 
dataplot = sb.heatmap(filtered_data.corr(), cmap="YlGnBu", annot=True)
